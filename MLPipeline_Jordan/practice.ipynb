# %% [markdown]
# # This file is simply to get started, mess around, test frameworks and database interactions, and try ML pipeline stuff...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ollama
import pytorch as pt

# %%
# From database, we'll have
