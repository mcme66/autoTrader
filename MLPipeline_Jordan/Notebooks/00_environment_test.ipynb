# %% [markdown]
# # This notebook is only used to verify our environment works

# %% [markdown]
# ### We'll use this notebook to install python packages, connect to the database, run small tensors, read CSVs, and plot graphs
