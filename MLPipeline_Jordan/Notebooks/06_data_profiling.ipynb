# %% [markdown]
# ## Here we work to understand incoming data before modeling
# - distributions
# - skewness
# - kurtosis
# - correlations
# - autocorrelation
# - stationarity checks
# - missingness patterns
# - outlier detection
# This notebook will be used for building intuition about the incoming data for time series work.
