# %% [markdown]
# ## Exploration notebook after gaining database access
# ### Here, we'll investigate questions:
# - What tables exist?
# - How many rows?
# - missing values
# - data types
# - sample queries
#
# Nothing gets committed to production from here
